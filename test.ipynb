# %%
import pandas as pd

# %%
df = pd.read_csv("maskdetection.csv")
df
# Out:
#       xmin  ymin  xmax  ymax         label             file  width  height  \
# 0      121   192   212   312     with_mask  maksssksksss107    301     400
# 1       48   294   164   400     with_mask  maksssksksss101    301     400
# 2        6   111    43   148  without_mask  maksssksksss110    400     267
# 3       22    20    49    46  without_mask  maksssksksss110    400     267
# 4       48    12    70    37     with_mask  maksssksksss110    400     267
# ...    ...   ...   ...   ...           ...              ...    ...     ...
# 4067    83    56   117    95     with_mask  maksssksksss364    400     267
# 4068   179    51   212    87     with_mask  maksssksksss364    400     267
# 4069   263    62   295   101     with_mask  maksssksksss364    400     267
# 4070   112    90   158   132     with_mask  maksssksksss378    400     188
# 4071   237    61   285   103     with_mask  maksssksksss378    400     188
#
# ...
