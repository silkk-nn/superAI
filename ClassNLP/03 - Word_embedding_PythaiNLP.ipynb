# %% [markdown]
# # Word embedding

# %% [markdown]
# ## pythainlp
#
# https://thainlp.org/pythainlp/docs/2.0/api/word_vector.html

# %%
# install pythainlp

# !pip install pythainlp==2.2.6
# Out:
# ...
#      |████████████████████████████████| 10.6 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 743 kB 42.0 MB/s
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires typing-extensions~=3.7.4, but you have typing-extensions 3.10.0.0 which is incompatible.
# ...

# %%
from pythainlp import word_vector
model = word_vector.get_model()
# Out:
# Corpus: thai2fit_wv
# - Downloading: thai2fit_wv 0.1
# 100%|██████████| 62452646/62452646 [00:00<00:00, 90357993.31it/s]

# %%
model['รถ'].shape
# Out:
# (300,)

# %%
print(model['รถ'])
# Out:
# [ 3.95423e-01 -2.15113e-01  3.16440e-02  4.40392e-01  1.50576e-01
#   1.07427e-01  2.23213e-01 -1.21626e-01 -1.49206e-01  4.99700e-03
#   3.15302e-01 -1.37916e-01  6.61000e-04  1.59766e-01  2.94377e-01
#   5.08628e-01 -5.20445e-01 -2.47302e-01 -6.35950e-02 -4.50599e-01
#   3.70289e-01  4.82321e-01  1.23845e-01 -1.09321e-01  2.40029e-01
#   6.79715e-01 -3.01410e-02 -3.62140e-02 -1.42747e-01 -4.11709e-01
#  -9.32980e-02  2.62873e-01 -1.29710e-01 -4.01474e-01 -5.82065e-01
#   2.48312e-01 -7.09230e-02 -5.88541e-01  1.77227e-01  3.43814e-01
#  -3.01240e-02 -2.58260e-02  1.74781e-01 -2.29691e-01 -4.48210e-02
#   3.68064e-01 -4.92988e-01  4.20930e-02  3.04279e-01 -3.60910e-02
#  -7.37570e-02  3.22040e-02  1.14922e-01 -1.32256e-01  6.75440e-02
#   4.51357e-01 -1.17540e-02 -2.48814e-01  5.83660e-02 -2.13375e-01
#  -2.38577e-01 -2.82134e-01 -3.03717e-01 -1.27692e-01 -3.38824e-01
#   3.55204e-01 -3.62447e-01 -4.36410e-02 -1.54663e-01 -2.85230e-01
# ...

# %% [markdown]
# ## embed one word

# %%
# embed each word in a sentence

from pythainlp.tokenize import word_tokenize
text = "โอเคบ่พวกเรารักภาษาบ้านเกิด"
words = word_tokenize(text, engine="newmm")

embedding = {}
for w in words:
    try:
        vec = thai2dict[w]
        embedding[w] = vec
    except:
        print('unknown word')

# %%
print(embedding)
# Out:
# {'โอเค': array([-4.05850e-02, -2.03250e-02,  8.98030e-02, -7.37070e-02,
#        -2.65790e-02,  2.29410e-02, -1.13465e-01,  4.81710e-02,
#        -7.22250e-02,  3.98150e-02, -1.09298e-01, -3.30860e-02,
#         4.56250e-02, -4.01700e-02,  7.73780e-02, -8.34000e-03,
#         6.15920e-02, -6.43300e-03,  1.24087e-01, -6.35150e-02,
#        -2.31510e-02, -1.61730e-02,  4.93200e-02, -3.45690e-02,
#        -3.20860e-02,  2.25460e-02,  7.70520e-02, -2.76540e-02,
#        -7.24890e-02,  5.53420e-02, -6.75440e-02, -8.30700e-03,
#        -9.40700e-03, -3.60570e-02, -4.29030e-02, -6.92130e-02,
#        -1.90710e-02,  3.54750e-02, -6.45400e-02, -8.67750e-02,
#        -9.63880e-02, -2.99400e-02, -6.80470e-02, -5.72280e-02,
#         6.93010e-02,  3.64100e-03, -3.16020e-02, -3.36440e-02,
#        -1.86316e-01,  2.24844e-01,  3.22990e-02,  3.29190e-02,
#        -2.43710e-02,  2.19200e-03, -1.03180e-02,  6.27460e-02,
#        -1.18760e-02, -6.90170e-02,  1.49771e-01, -2.95890e-02,
# ...

# %% [markdown]
# ## embed whole sentence

# %%
from pythainlp.word_vector import sentence_vectorizer

sentence = 'อ้วนเสี้ยวเข้ายึดแคว้นกิจิ๋ว ในปี พ.ศ. 735'
sent_embed = sentence_vectorizer(sentence, use_mean=True)
print(sent_embed.shape)
print(sent_embed)
# Out:
# (1, 300)
# [[-0.00421414 -0.08881307  0.05081136 -0.05632929 -0.06607185  0.03059357
#   -0.113882   -0.00074836  0.05035743  0.02914307 -0.10464029  0.019918
#    0.03639814  0.05301008 -0.13749507 -0.11160429 -0.1200085   0.03817136
#    0.00825643  0.07276429 -0.02891879  0.07737672  0.03190322  0.01445172
#    0.03933064 -0.00109957 -0.03962529  0.0237405   0.04662343 -0.14464793
#    0.00491671 -0.02475222 -0.07190765  0.03091221 -0.06995743  0.10142678
#   -0.02263322 -0.00103571 -0.04209771  0.134604   -0.06673093  0.12755057
#    0.01739657  0.00954893  0.065684    0.08892178 -0.00415257  0.04165
#   -0.00776729  0.014462   -0.16988735 -0.04048207  0.10397229  0.01065336
#    0.00573429  0.00805471 -0.00171257 -0.06774764  0.08962522 -0.05613628
#    0.134607   -0.01444514  0.046851   -0.05872029  0.0378055   0.04262343
#   -0.08296714 -0.02287643  0.11975636 -0.1233605   0.08546736  0.00974407
#    0.10581521 -0.10303729 -0.03329493  0.055844    0.00346086 -0.14839286
# ...

# %% [markdown]
# ## fasttext
#
# https://fasttext.cc/docs/en/support.html

# %%
# install

# !git clone https://github.com/facebookresearch/fastText.git
# %cd fastText
# !pip install .
# Out:
# Cloning into 'fastText'...
# remote: Enumerating objects: 3854, done.
# remote: Total 3854 (delta 0), reused 0 (delta 0), pack-reused 3854
# Receiving objects: 100% (3854/3854), 8.22 MiB | 23.59 MiB/s, done.
# Resolving deltas: 100% (2417/2417), done.
# /content/fastText
# Processing /content/fastText
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Using cached pybind11-2.7.1-py2.py3-none-any.whl (200 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3091247 sha256=fa5eed13bc37f819a3c7de446ab479d8e2f932d9c2aebd783b4b28eebfbb1084
# ...

# %%
# test install
# %cd ..
import fasttext
# Out:
# /content

# %%
# download model for Thai
# https://fasttext.cc/docs/en/pretrained-vectors.html

# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.th.zip
# Out:
# --2021-08-25 03:45:37--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.th.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 104.22.74.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2602669751 (2.4G) [application/zip]
# Saving to: ‘wiki.th.zip’
#
# wiki.th.zip         100%[===================>]   2.42G  27.8MB/s    in 89s
#
# 2021-08-25 03:47:07 (27.8 MB/s) - ‘wiki.th.zip’ saved [2602669751/2602669751]

# %%
# !ls
# Out:
# fastText  sample_data  wiki.th.zip

# %%
# !unzip wiki.th.zip
# Out:
# Archive:  wiki.th.zip
#   inflating: wiki.th.bin
#   inflating: wiki.th.vec

# %%
import fasttext
ft = fasttext.load_model('wiki.th.bin')
ft.get_dimension()
# Out:
# 300

# %%
vec = ft.get_word_vector('สวัสดี')
print(vec.shape)
# Out:
# (300,)

# %%
print(vec)
# Out:
# [-1.40922278e-01 -2.14025930e-01  2.23148569e-01  3.40930194e-01
#  -1.83633491e-01  5.52912913e-02 -2.25355029e-01 -2.13225305e-01
#   6.82474077e-02 -1.13902040e-01 -2.92068928e-01  1.70883626e-01
#   4.28550720e-01 -5.10468781e-01 -2.14167058e-01 -1.62830070e-01
#   6.89881295e-03  8.23369697e-02  1.94322690e-01 -3.16973403e-02
#   1.82227895e-01 -2.46869493e-02 -3.32049350e-03 -3.02666962e-01
#  -7.32044429e-02  2.96417903e-03 -1.79425597e-01 -2.63970524e-01
#   4.65851799e-02 -3.22241843e-01 -7.43004456e-02 -1.69766564e-02
#   2.32714221e-01 -9.49978009e-02 -1.27914131e-01  3.32484804e-02
#   7.60449469e-02 -3.73936087e-01  2.17553884e-01  5.15773185e-02
#   2.24470630e-01  1.04175225e-01  3.58020484e-01 -2.88105607e-01
#   4.44976948e-02 -2.64823645e-01 -3.73638660e-01 -4.44457352e-01
#   1.42011065e-02  7.17673600e-02  1.37013420e-01 -9.81970802e-02
#   1.46360576e-01  2.04724088e-01  3.57836008e-01 -1.82873473e-01
# ...
